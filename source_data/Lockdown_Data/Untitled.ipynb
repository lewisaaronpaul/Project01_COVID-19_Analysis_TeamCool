# %%
import pandas as pd
import os

# %%
csv_file = os.path.join('Global_Mobility_Report.csv')

# %%
mob_df = pd.read_csv(csv_file)
# Out:
# /Users/tyler/opt/anaconda3/envs/ProjectWork/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3062: DtypeWarning: Columns (3) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
mob_df
# Out:
#        country_region_code        country_region       sub_region_1  \
# 0                       AE  United Arab Emirates                NaN
# 1                       AE  United Arab Emirates                NaN
# 2                       AE  United Arab Emirates                NaN
# 3                       AE  United Arab Emirates                NaN
# 4                       AE  United Arab Emirates                NaN
# ...                    ...                   ...                ...
# 547917                  ZW              Zimbabwe  Midlands Province
# 547918                  ZW              Zimbabwe  Midlands Province
# 547919                  ZW              Zimbabwe  Midlands Province
# 547920                  ZW              Zimbabwe  Midlands Province
# 547921                  ZW              Zimbabwe  Midlands Province
#
#        sub_region_2 iso_3166_2_code  census_fips_code        date  \
# 0               NaN             NaN               NaN  2020-02-15
# ...
