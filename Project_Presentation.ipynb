# %% [markdown]
# # What's The Story?
# # COVID-19 in the USA: Things you didn't know.
# ### We were motivated to analyse COVID-19 data to understand
# 1. What has happened so far.
# 1. The impact on different parts of the country.
# 1. The factors driving regional differences.
#
# ### Why? It is highly topical, personally relevant, and a useful test of our skills.
#
# #### Aaron Lewis, Tyler Ward, Ross Davidson.
# ##### Rice University Data Analytics Boot Camp.
# ##### Project 1 Presentation.
# ##### 25 June 2020.

# %% [markdown]
# # What Data?
# ### Data Sources
# 1. Cases and Deaths by County from USAFacts.org, aggregating data from CDC, state- and local- public health agencies.
# 2. Census Data from Census.gov.
# 3. Healthcare data from HRSA.gov.
# 4. Data collected up to 15 June 2020.
#
# ### Data Cleanup
# 4. Cases and Deaths data required clean up prior to merging, esp. as county names were different.
# 5. HSRA data needed extensive wrangling to isolate a county-level score.
# 6. Census API took some work to understand.
#
# ### Sneak Peak
# 7. Charts of which areas have been most and least affected
# 8. Maps of where the virus has spread…. And where it hasn’t reached.
# 9. Statistical Analysis of demographic factors driving case rates.

# %% [markdown]
# # Question 1: How Did We Get Here?

# %%
from IPython.display import Image
print('Graph shows a dramatic rise in cases from mid March, then a slower rise in deaths.')
Image(filename='output_data/Graph_Reported_Cases_and_Deaths.png')
# Out:
# Graph shows a dramatic rise in cases from mid March, then a slower rise in deaths.

# %%
print('From late March, the daily increase of reported deaths and cases slowed.')
print('The data shows a weekly seasonality, hinting at possible reporting bias in the data.')
Image(filename='output_data/Graph_Change_in_Reported_Cases_and_Deaths.png')
# Out:
# From late March, the daily increase of reported deaths and cases slowed.
# The data shows a weekly seasonality, hinting at possible reporting bias in the data.

# %%
print('Approaching saturation by June.')
print('Interestingly, on 15 June 2020, there were still 161 counties reporting zero cases.')
print('0.36% of counties reported some cases but zero deaths.')
Image(filename='output_data/Graph_Counties_Reporting_Cases_and_Deaths.png')
# Out:
# Approaching saturation by June.
# Interestingly, on 15 June 2020, there were still 161 counties reporting zero cases.
# 0.36% of counties reported some cases but zero deaths.

# %% [markdown]
# # Question 2: Are All States Created Equal?

# %%
print('It is not just population.')
Image(filename='output_data/Graph_State_Population_and_Deaths.png')
# Out:
# It is not just population.

# %%
print('There is quite a variation in mortality (deaths/cases) across the States.')
print('And it is not just New York.')
Image(filename='output_data/Graph_State_and_Death_Rate.png')
# Out:
# There is quite a variation in mortality (deaths/cases) across the States.
# And it is not just New York.

# %%
print('Box and Whisker Analysis suggests these outliers are significant.')
Image(filename='output_data/Graph_BoxAndWhisker_State_Death_Rate.png')
# Out:
# Box and Whisker Analysis suggests these outliers are significant.

# %% [markdown]
# # Question 3: Where Is This Happening?

# %%
print('When mapped by county, it looks pretty widespread.')
Image(filename='output_data/Map_County__Cases_Heat_Map.png')
# Out:
# When mapped by county, it looks pretty widespread.

# %%
print('The North-Eastern States have the highest counts.')
Image(filename='output_data/Map_State_Highest_Death_Rate2.png')
# Out:
# The North-Eastern States have the highest counts.

# %%
print('But Latitute is not a good explanation.')
Image(filename='output_data/Graph_State__Deaths_Lat.png')
# Out:
# But Latitute is not a good explanation.

# %% [markdown]
# # So What Is Driving It?

# %% [markdown]
# # Question 4: Is It Access To Healthcare?

# %%
print('Counties with the worst HSPA score generally have higher Total Deaths per capita.')
Image(filename='output_data/HPSA_SCOREvsTotal_Deaths.png', width="500")
# Out:
# Counties with the worst HSPA score generally have higher Total Deaths per capita.

# %%
print('However, that relationship is weaker when we look at Mortality.')
print('Surprisingly, counties with better health care do not seem to have better survival rates.')
Image(filename='output_data/HPSAScore_v_CountyMortality.png', width="500")
# Out:
# However, that relationship is weaker when we look at Mortality.
# Surprisingly, counties with better health care do not seem to have better survival rates.

# %% [markdown]
# # Question 5: Is It Age and Health Insurance?

# %%
print('Cases v Over 65 with no Health Insurance shows some relationship.')
print('Especially in the North East Region.')
print('But the other regions do not have a strong relationship')
Image(filename='output_data/Graph_Reported_Cases_and_Over_65.png')
# Out:
# Cases v Over 65 with no Health Insurance shows some relationship.
# Especially in the North East Region.
# But the other regions do not have a strong relationship

# %% [markdown]
# # Question 6: Is It Poverty?

# %%
print('Poverty levels show a much stronger relationship to cases across regions.')
Image(filename='output_data/Graph_Reported_Cases_and_Poverty_Level.png')
# Out:
# Poverty levels show a much stronger relationship to cases across regions.

# %% [markdown]
# # Wrap Up
# ### We know more than we did before!
# 1. Primary finding: there is a statistically significantly difference across the USA.
# 1. Some of that difference can be explained by demographic factors.
# 1. Contrary to our expectation, access to health care or age do not seem to be signficant factors.
# 1. However, poverty levels appear to affect cases.
# 1. There are also clearly other factors at work, and the data is still evolving.
# 1. This has implications for how we understand and address what has happened.
